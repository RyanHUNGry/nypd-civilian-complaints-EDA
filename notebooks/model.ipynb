# %% [markdown]
# We will predict how long, in days, a complaint takes to be closed. This is a regression problem.

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import seaborn as sns

pd.set_option('display.max_columns', None) # Stretches dataframe output to display every columnn

# %%
filepath = "../data/complaints_cleaned.csv"
complaints = pd.read_csv(filepath, index_col= 0)
complaints.head()
# Out:
#    unique_mos_id first_name last_name command_now  shield_no  complaint_id  \
# 0        10004.0   Jonathan      Ruiz     078 PCT     8409.0       42835.0
# 1        10007.0       John     Sears     078 PCT     5952.0       24601.0
# 2        10007.0       John     Sears     078 PCT     5952.0       24601.0
# 3        10007.0       John     Sears     078 PCT     5952.0       26146.0
# 4        10009.0      Noemi    Sierra     078 PCT    24058.0       40253.0
#
#    month_received  year_received  month_closed  year_closed  \
# 0             7.0         2019.0           5.0       2020.0
# 1            11.0         2011.0           8.0       2012.0
# 2            11.0         2011.0           8.0       2012.0
# 3             7.0         2012.0           9.0       2013.0
# 4             8.0         2018.0           2.0       2019.0
#
#   command_at_incident rank_abbrev_incident rank_abbrev_now mos_ethnicity  \
# 0             078 PCT                  POM             POM      Hispanic
# 1                PBBS                  POM             POM         White
# 2                PBBS                  POM             POM         White
# 3                PBBS                  POM             POM         White
# 4             078 PCT                  POF             POF      Hispanic
#
#   mos_gender  mos_age_incident complainant_ethnicity complainant_gender  \
# 0          M              32.0                 Black             Female
# 1          M              24.0                 Black               Male
# 2          M              24.0                 Black               Male
# 3          M              25.0                 Black               Male
# 4          F              39.0                   NaN                NaN
#
#    complainant_age_incident           fado_type                    allegation  \
# 0                      38.0  Abuse of Authority  Failure to provide RTKA card
# 1                      26.0         Discourtesy                        Action
# 2                      26.0  Offensive Language                          Race
# 3                      45.0  Abuse of Authority                      Question
# 4                      16.0               Force                Physical force
#
#    precinct                                contact_reason  \
# 0      78.0                       Report-domestic dispute
# 1      67.0                              Moving violation
# 2      67.0                              Moving violation
# 3      67.0  PD suspected C/V of violation/crime - street
# 4      67.0                                Report-dispute
#
#                 outcome_description                         board_disposition  \
# 0  No arrest made or summons issued  Substantiated (Command Lvl Instructions)
# 1   Moving violation summons issued                   Substantiated (Charges)
# 2   Moving violation summons issued                   Substantiated (Charges)
# 3  No arrest made or summons issued                   Substantiated (Charges)
# 4    Arrest - other violation/crime      Substantiated (Command Discipline A)
#
#   date_received date_closed days_taken   rank_incident        rank_now  \
# 0    2019-07-01  2020-05-01   305 days  Police Officer  Police Officer
# 1    2011-11-01  2012-08-01   274 days  Police Officer  Police Officer
# 2    2011-11-01  2012-08-01   274 days  Police Officer  Police Officer
# 3    2012-07-01  2013-09-01   427 days  Police Officer  Police Officer
# 4    2018-08-01  2019-02-01   184 days  Police Officer  Police Officer
#
#    complainant_won
# 0              1.0
# 1              1.0
# 2              1.0
# 3              1.0
# 4              1.0

# %% [markdown]
# We won't focus on imputation for this project. The filtered dataset will still have enough values to train a model on (26k entries).

# %%
complaints['days_taken'] = pd.to_numeric(complaints['days_taken'].str.split().str[0]) # Reformat days_taken to integer
complaints = complaints.dropna().drop(columns = ['complaint_id', 'unique_mos_id', 'shield_no']) # Drop all rows with missing data and drop all unique identification columns

# %%
# We conducted inferential tests to see if there was a relationship between case duration and complainant gender/age/ethnicity so let's use those columns to train a baseline model
X_train, X_test, y_train, y_test = train_test_split(complaints.drop(columns = ['days_taken']), complaints['days_taken'], shuffle= True, test_size=0.2)
display(X_train.head())
display(y_train.head())
# Out:
#       first_name   last_name command_now  month_received  year_received  \
# 6535      Freddy   Dominguez     D-E T/F             8.0         2004.0
# 13405       John       Zanca      I.A.B.             1.0         2015.0
# 424         Mark       Xylas     079 PCT             7.0         2015.0
# 20159     Norman  Grandstaff        PBBS             2.0         2006.0
# 9983       David    Nisthaus       E S U            12.0         2004.0
#
#        month_closed  year_closed command_at_incident rank_abbrev_incident  \
# 6535           10.0       2005.0             043 PCT                  SGT
# 13405           9.0       2015.0             040 PCT                  POM
# 424            10.0       2015.0             081 PCT                  POM
# 20159           5.0       2006.0             070 PCT                  SGT
# 9983            1.0       2006.0             NARCBMN                  SGT
#
#       rank_abbrev_now mos_ethnicity mos_gender  mos_age_incident  \
# 6535              SDS      Hispanic          M              38.0
# 13405             SGT         White          M              24.0
# 424               SGT         White          M              28.0
# 20159             INS         White          M              30.0
# 9983               LT      Hispanic          M              39.0
#
#       complainant_ethnicity complainant_gender  complainant_age_incident  \
# 6535                  Black               Male                      50.0
# 13405                 Black               Male                      33.0
# 424                   Black               Male                      21.0
# 20159                 Black               Male                      26.0
# 9983                  Black               Male                      44.0
#
#                 fado_type                             allegation  precinct  \
# 6535   Abuse of Authority                           Vehicle stop      43.0
# 13405  Abuse of Authority                     Search (of person)      40.0
# 424    Abuse of Authority                         Vehicle search      81.0
# 20159               Force                         Physical force      70.0
# 9983   Abuse of Authority  Refusal to provide name/shield number      24.0
#
#                                      contact_reason  \
# 6535     PD suspected C/V of violation/crime - bldg
# 13405                        Other violation of VTL
# 424      PD suspected C/V of violation/crime - auto
# 20159  PD suspected C/V of violation/crime - street
# 9983                    Execution of search warrant
#
#                   outcome_description board_disposition date_received  \
# 6535   Arrest - other violation/crime   Unsubstantiated    2004-08-01
# 13405  Arrest - other violation/crime   Unsubstantiated    2015-01-01
# 424    Arrest - other violation/crime        Exonerated    2015-07-01
# 20159    Summons - disorderly conduct        Exonerated    2006-02-01
# 9983   Arrest - other violation/crime   Unsubstantiated    2004-12-01
#
#       date_closed   rank_incident                  rank_now  complainant_won
# 6535   2005-10-01        Sergeant  Sergeant Detective Squad              0.0
# 13405  2015-09-01  Police Officer                  Sergeant              0.0
# 424    2015-10-01  Police Officer                  Sergeant              0.0
# 20159  2006-05-01        Sergeant                 Inspector              0.0
# 9983   2006-01-01        Sergeant                Lieutenant              0.0
# 6535     426.0
# 13405    243.0
# 424       92.0
# 20159     89.0
# 9983     396.0
# Name: days_taken, dtype: float64

# %%
ct = ColumnTransformer([("ohe", OneHotEncoder(), ['complainant_gender', 'complainant_ethnicity']), ('age_ignore' , 'passthrough', ['complainant_age_incident'])], remainder='drop')
pl = Pipeline([('ct', ct), ('lr', LinearRegression())])
pl.fit(X_train, y_train)
pl.named_steps['ct'].transform(X_train).toarray()
# Out:
# array([[ 0.,  0.,  1., ...,  0.,  0., 50.],
#        [ 0.,  0.,  1., ...,  0.,  0., 33.],
#        [ 0.,  0.,  1., ...,  0.,  0., 21.],
#        ...,
#        [ 1.,  0.,  0., ...,  0.,  0., 28.],
#        [ 0.,  0.,  1., ...,  0.,  0., 24.],
#        [ 0.,  0.,  1., ...,  1.,  0., 25.]])

# %%
print(f"Baseline R^2: {pl.score(X_test, y_test)}")
print(f"Baseline MSE: {mean_squared_error(pl.predict(X_test), y_test)}")
# Out:
# Baseline R^2: 0.014160187406212388
# Baseline MSE: 21620.405516546394
